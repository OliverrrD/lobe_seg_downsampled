# %%
import numpy as np
import matplotlib.pyplot as plt

from sklearn.model_selection import learning_curve
from sklearn.model_selection import ShuffleSplit

# %%
axes = plt.subplots(1, 1, figsize=(5, 5))
labels = ['Dim=1', 'Dim=2', 'Dim=3', 'Dim=5', 'Dim=7', 'Dim=10']
net2_means = np.array([0.777, 0.768, 0.850, 0.865, 0.746, 0.772])
net1_means = np.array([0.826, 0.826, 0.826, 0.826, 0.826, 0.826])
#women_means = [25, 32, 34, 20, 25]
net1_std = np.array([0.041] * 6)
net2_std = np.array([0.058, 0.066, 0.054, 0.050, 0.071, 0.062])
ind = np.arange(len(labels))  # the label locations
width = 0.1  # the width of the bars
fig, ax = plt.subplots(figsize = (8, 6))

rects1 = ax.plot(ind , net1_means,  "--", label='Net1')
rects1 = ax.fill_between(ind, net1_means - net1_std, net1_means + net1_std, alpha = 0.1)
rects2 = ax.plot(ind , net2_means,  "*-", label='Net2')
rects2 = ax.fill_between(ind, net2_means - net2_std, net2_means + net2_std, alpha = 0.1)
label = ['0.777(0.058)', '0.768(0.066)', '0.850(0.054)', '0.865(0.050)', '0.746(0.071)', '0.772(0.062)']
cnt = 0

# for x,y in zip(ind,net2_means):

#    # label = "{:.3f}".format(y)
    
#     plt.annotate(label[cnt], # this is the text
#                  (x,y), # this is the point to label
#                  textcoords="offset points", # how to position the text
#                  xytext=(0,-15), # distance from text to points (x,y)
#                  fontsize = 15,
#                  ha='left') # horizontal alignment can be left, right or center
#     cnt += 1
    
# plt.annotate('0.826(0.041)', # this is the text
#                  (ind[0],net1_means[0]), # this is the point to label
#                  textcoords="offset points", # how to position the text
#                  xytext=(0,10), # distance from text to points (x,y)
#                  fontsize = 15,
#                  ha='left') # 
# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('mean AUC (five-fold) ', fontsize = 15)
#ax.set_title('Distribution of Subjects', fontsize = 20)
ax.set_xticks(ind)
ax.set_xticklabels(labels)
#ax.legend()
ax.legend(fontsize = 15)

plt.ylim(0.60, 0.95)

fig.tight_layout()
plt.xticks(fontsize = 15)
plt.yticks(fontsize = 15)
plt.show()
